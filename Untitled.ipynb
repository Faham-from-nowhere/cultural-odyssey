# %%
import pandas as pd

# Load your datasets
cultural_hotspots = pd.read_csv('Top Indian Places to Visit.csv')
tourism_footfall = pd.read_csv('India-Tourism-Statistics-2021-Table-5.1.2_0.csv')

# Preprocessing Function
def preprocess_data(df):
    # Ensure column names are strings
    df.columns = df.columns.astype(str)
    
    # Handle missing values
    df.fillna('Unknown', inplace=True)
    
    # Normalize column names
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
    
    # Convert date columns to datetime format if available
    for col in df.columns:
        if 'date' in col:
            df[col] = pd.to_datetime(df[col], errors='coerce')
    
    return df

# Preprocess datasets
cultural_hotspots = preprocess_data(cultural_hotspots)
tourism_footfall = preprocess_data(tourism_footfall)

# Save cleaned data
cultural_hotspots.to_csv('cleaned_cultural_hotspots.csv', index=False)
tourism_footfall.to_csv('cleaned_tourism_footfall.csv', index=False)
gov_initiatives.to_csv('cleaned_gov_initiatives.csv', index=False)

print("Preprocessing Complete. Cleaned CSVs are saved.")
# Out:
# Preprocessing Complete. Cleaned CSVs are saved.
# C:\Users\mohdf\AppData\Local\Temp\ipykernel_16228\2070401100.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Unknown', inplace=True)

# %%
import pandas as pd
from snowflake.connector import connect

# Load the cleaned datasets
cultural_hotspots = pd.read_csv('cleaned_cultural_hotspots.csv')
tourism_footfall = pd.read_csv('cleaned_tourism_footfall.csv')


# Step 1: Snowflake Connection Setup
conn = connect(
    user='FAHAM2005',
    password='fKrx99Ejj3ZrEAd',
    account='DPNFGOL-FS07172',  # Your Snowflake account identifier
    warehouse='BOB',
    database='CULTURAL_ODYSSEY',
    schema='PUBLIC'
)

cursor = conn.cursor()

# Step 2: Create Tables in Snowflake
tables = {
    'CULTURAL_HOTSPOTS': cultural_hotspots,
    'TOURISM_FOOTFALL': tourism_footfall
}

for table_name, dataframe in tables.items():
    # Properly quote column names
    columns = ', '.join([f'"{col}" VARCHAR' for col in dataframe.columns])
    
    create_table_query = f"""
    CREATE OR REPLACE TABLE {table_name} (
        {columns}
    )
    """
    print("Executing create table query:")
    print(create_table_query)
    cursor.execute(create_table_query)
    print(f"Table {table_name} created successfully.")
print(f"CULTURAL_HOTSPOTS shape: {cultural_hotspots.shape}")
print(f"TOURISM_FOOTFALL shape: {tourism_footfall.shape}")

# Step 3: Insert Data into Snowflake
def insert_data_to_snowflake(table_name, dataframe):
    cols = ', '.join(dataframe.columns)
    values = ', '.join(['%s'] * len(dataframe.columns))
    insert_query = f"INSERT INTO {table_name} ({cols}) VALUES ({values})"
    
    for _, row in dataframe.iterrows():
        cursor.execute(insert_query, tuple(row))

def insert_data_to_snowflake(table_name, dataframe):
    cols = ', '.join([f'"{col}"' for col in dataframe.columns])
    values = ', '.join(['%s'] * len(dataframe.columns))
    insert_query = f"INSERT INTO {table_name} ({cols}) VALUES ({values})"
    
    for idx, row in dataframe.iterrows():
        try:
            cursor.execute(insert_query, tuple(row))
        except Exception as e:
            print(f"Error inserting row {idx}: {e}")
    cursor.connection.commit()
    conn.commit()

# Step 4: Verification Queries
cursor.execute("SELECT COUNT(*) FROM CULTURAL_HOTSPOTS")
print(f"Total Records in CULTURAL_HOTSPOTS: {cursor.fetchone()[0]}")

cursor.execute("SELECT COUNT(*) FROM TOURISM_FOOTFALL")
print(f"Total Records in TOURISM_FOOTFALL: {cursor.fetchone()[0]}")

# Step 5: Close Connection
cursor.close()
conn.close()
print("Snowflake connection closed.")
# Out:
# Executing create table query:
#
#     CREATE OR REPLACE TABLE CULTURAL_HOTSPOTS (
#         "unnamed:_0" VARCHAR, "zone" VARCHAR, "state" VARCHAR, "city" VARCHAR, "name" VARCHAR, "type" VARCHAR, "establishment_year" VARCHAR, "time_needed_to_visit_in_hrs" VARCHAR, "google_review_rating" VARCHAR, "entrance_fee_in_inr" VARCHAR, "airport_with_50km_radius" VARCHAR, "weekly_off" VARCHAR, "significance" VARCHAR, "dslr_allowed" VARCHAR, "number_of_google_review_in_lakhs" VARCHAR, "best_time_to_visit" VARCHAR
#     )
#
# Table CULTURAL_HOTSPOTS created successfully.
# Executing create table query:
#
#     CREATE OR REPLACE TABLE TOURISM_FOOTFALL (
#         "s._no." VARCHAR, "states/uts_*" VARCHAR, "domestic_-2019" VARCHAR, "foreign_-_2019" VARCHAR, "domestic_-2020" VARCHAR, "foreign_-_2020" VARCHAR, "growth_rate_-_dtv__2020/19" VARCHAR, "growth_rate_-_ftv_2020/19" VARCHAR
#     )
#
# Table TOURISM_FOOTFALL created successfully.
# CULTURAL_HOTSPOTS shape: (325, 16)
# TOURISM_FOOTFALL shape: (40, 8)
# Total Records in CULTURAL_HOTSPOTS: 0
# Total Records in TOURISM_FOOTFALL: 0
# Snowflake connection closed.

# %%
# Step 1: Snowflake Connection Setup
conn = connect(
    user='FAHAM2005',
    password='fKrx99Ejj3ZrEAd',
    account='DPNFGOL-FS07172',  # Your Snowflake account identifier
    warehouse='BOB',
    database='CULTURAL_ODYSSEY',
    schema='PUBLIC'
)

cursor = conn.cursor()
cursor.execute("SELECT COUNT(*) FROM CULTURAL_HOTSPOTS")
print(f"Total Records in CULTURAL_HOTSPOTS: {cursor.fetchone()[0]}")

cursor.execute("SELECT COUNT(*) FROM TOURISM_FOOTFALL")
print(f"Total Records in TOURISM_FOOTFALL: {cursor.fetchone()[0]}")

# Example: preview first 5 rows
cursor.execute("SELECT * FROM CULTURAL_HOTSPOTS LIMIT 5")
for row in cursor.fetchall():
    print(row)
# Out:
# Total Records in CULTURAL_HOTSPOTS: 325
# Total Records in TOURISM_FOOTFALL: 40
# ('0', 'Northern', 'Delhi', 'Delhi', 'India Gate', 'War Memorial', '1921', '0.5', '4.6', '0', 'Yes', 'Unknown', 'Historical', 'Yes', '2.6', 'Evening')
# ('1', 'Northern', 'Delhi', 'Delhi', "Humayun's Tomb", 'Tomb', '1572', '2.0', '4.5', '30', 'Yes', 'Unknown', 'Historical', 'Yes', '0.4', 'Afternoon')
# ('2', 'Northern', 'Delhi', 'Delhi', 'Akshardham Temple', 'Temple', '2005', '5.0', '4.6', '60', 'Yes', 'Unknown', 'Religious', 'No', '0.4', 'Afternoon')
# ('3', 'Northern', 'Delhi', 'Delhi', 'Waste to Wonder Park', 'Theme Park', '2019', '2.0', '4.1', '50', 'Yes', 'Monday', 'Environmental', 'Yes', '0.27', 'Evening')
# ('4', 'Northern', 'Delhi', 'Delhi', 'Jantar Mantar', 'Observatory', '1724', '2.0', '4.2', '15', 'Yes', 'Unknown', 'Scientific', 'Yes', '0.31', 'Morning')

# %%
# Downgrade to stable datasets version
# !pip install datasets==2.8.0 --quiet
from datasets import load_dataset

# === Dataset 7: Indian State Tourism Statistics ===
print("Downloading Dataset 7: Indian State Tourism Statistics...")
dataset_7 = load_dataset("cyberblip/Travel_india")
dataset_7['train'].to_pandas().to_csv('Indian_State_Tourism_Statistics.csv', index=False)
print("Dataset 7 saved as Indian_State_Tourism_Statistics.csv\n")

# === Dataset 9: Indian Heritage Sites ===
print("Downloading Dataset 9: Indian Heritage Sites...")
dataset_9 = load_dataset("deepkaria/indian-culture-dataset")
dataset_9['train'].to_pandas().to_csv('Indian_Heritage_Sites.csv', index=False)
print("Dataset 9 saved as Indian_Heritage_Sites.csv\n")

print("✅ All datasets downloaded and saved successfully.")
# Out:
# Downloading Dataset 7: Indian State Tourism Statistics...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       5 # === Dataset 7: Indian State Tourism Statistics ===
#       6 print("Downloading Dataset 7: Indian State Tourism Statistics...")
# ----> 7 dataset_7 = load_dataset("cyberblip/Travel_india")
#       8 dataset_7['train'].to_pandas().to_csv('Indian_State_Tourism_Statistics.csv', index=False)
#       9 print("Dataset 7 saved as Indian_State_Tourism_Statistics.csv\n")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\datasets\load.py:1734, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, **config_kwargs)
#    1731 ignore_verifications = ignore_verifications or save_infos
#    1733 # Create a dataset builder
# -> 1734 builder_instance = load_dataset_builder(
#    1735     path=path,
#    1736     name=name,
#    1737     data_dir=data_dir,
#    1738     data_files=data_files,
#    1739     cache_dir=cache_dir,
#    1740     features=features,
#    1741     download_config=download_config,
#    1742     download_mode=download_mode,
#    1743     revision=revision,
#    1744     use_auth_token=use_auth_token,
#    1745     **config_kwargs,
#    1746 )
#    1748 # Return iterable dataset in case of streaming
#    1749 if streaming:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\datasets\load.py:1492, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, use_auth_token, **config_kwargs)
#    1490     download_config = download_config.copy() if download_config else DownloadConfig()
#    1491     download_config.use_auth_token = use_auth_token
# -> 1492 dataset_module = dataset_module_factory(
#    1493     path,
#    1494     revision=revision,
#    1495     download_config=download_config,
#    1496     download_mode=download_mode,
#    1497     data_dir=data_dir,
#    1498     data_files=data_files,
#    1499 )
#    1501 # Get dataset builder class from the processing script
#    1502 builder_cls = import_main_class(dataset_module.module_path)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\datasets\load.py:1216, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, **download_kwargs)
#    1211             if isinstance(e1, FileNotFoundError):
#    1212                 raise FileNotFoundError(
#    1213                     f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory. "
#    1214                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1215                 ) from None
# -> 1216             raise e1 from None
#    1217 else:
#    1218     raise FileNotFoundError(
#    1219         f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory."
#    1220     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\datasets\load.py:1202, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, **download_kwargs)
#    1187         return HubDatasetModuleFactoryWithScript(
#    1188             path,
#    1189             revision=revision,
#    (...)   1192             dynamic_modules_path=dynamic_modules_path,
#    1193         ).get_module()
#    1194     else:
#    1195         return HubDatasetModuleFactoryWithoutScript(
#    1196             path,
#    1197             revision=revision,
#    1198             data_dir=data_dir,
#    1199             data_files=data_files,
#    1200             download_config=download_config,
#    1201             download_mode=download_mode,
# -> 1202         ).get_module()
#    1203 except Exception as e1:  # noqa: all the attempts failed, before raising the error we should check if the module is already cached.
#    1204     try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\datasets\load.py:766, in HubDatasetModuleFactoryWithoutScript.get_module(self)
#     755 def get_module(self) -> DatasetModule:
#     756     hfh_dataset_info = hf_api_dataset_info(
#     757         HfApi(config.HF_ENDPOINT),
#     758         self.name,
#    (...)    761         timeout=100.0,
#     762     )
#     763     patterns = (
#     764         sanitize_patterns(self.data_files)
#     765         if self.data_files is not None
# --> 766         else get_data_patterns_in_dataset_repository(hfh_dataset_info, self.data_dir)
#     767     )
#     768     data_files = DataFilesDict.from_hf_repo(
#     769         patterns,
#     770         dataset_info=hfh_dataset_info,
#     771         base_path=self.data_dir,
#     772         allowed_extensions=ALL_ALLOWED_EXTENSIONS,
#     773     )
#     774     module_names = {
#     775         key: infer_module_for_data_files(data_files_list, use_auth_token=self.download_config.use_auth_token)
#     776         for key, data_files_list in data_files.items()
#     777     }
#
# File ~\AppData\Roaming\Python\Python312\site-packages\datasets\data_files.py:675, in get_data_patterns_in_dataset_repository(dataset_info, base_path)
#     673 resolver = partial(_resolve_single_pattern_in_dataset_repository, dataset_info, base_path=base_path)
#     674 try:
# --> 675     return _get_data_files_patterns(resolver)
#     676 except FileNotFoundError:
#     677     raise EmptyDatasetError(
#     678         f"The dataset repository at '{dataset_info.id}' doesn't contain any data files"
#     679     ) from None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\datasets\data_files.py:236, in _get_data_files_patterns(pattern_resolver)
#     234 try:
#     235     for pattern in patterns:
# --> 236         data_files = pattern_resolver(pattern)
#     237         if len(data_files) > 0:
#     238             non_empty_splits.append(split)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\datasets\data_files.py:486, in _resolve_single_pattern_in_dataset_repository(dataset_info, pattern, base_path, allowed_extensions)
#     484 else:
#     485     base_path = "/"
# --> 486 glob_iter = [PurePath(filepath) for filepath in fs.glob(PurePath(pattern).as_posix()) if fs.isfile(filepath)]
#     487 matched_paths = [
#     488     filepath
#     489     for filepath in glob_iter
#    (...)    496     )
#     497 ]  # ignore .ipynb and __pycache__, but keep /../
#     498 if allowed_extensions is not None:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\fsspec\spec.py:611, in AbstractFileSystem.glob(self, path, maxdepth, **kwargs)
#     607         depth = None
#     609 allpaths = self.find(root, maxdepth=depth, withdirs=True, detail=True, **kwargs)
# --> 611 pattern = glob_translate(path + ("/" if ends_with_sep else ""))
#     612 pattern = re.compile(pattern)
#     614 out = {
#     615     p: info
#     616     for p, info in sorted(allpaths.items())
#    (...)    621     )
#     622 }
#
# File ~\AppData\Roaming\Python\Python312\site-packages\fsspec\utils.py:731, in glob_translate(pat)
#     729     continue
#     730 elif "**" in part:
# --> 731     raise ValueError(
#     732         "Invalid pattern: '**' can only be an entire path component"
#     733     )
#     734 if part:
#     735     results.extend(_translate(part, f"{not_sep}*", not_sep))
#
# ValueError: Invalid pattern: '**' can only be an entire path component

# %%
import datasets
print(datasets.__version__)
# Out:
# 3.6.0

# %%
import pandas as pd
from snowflake.connector import connect

# === Step 0: Load your datasets ===
train_csv = pd.read_csv('TRAIN.csv')
train_parquet = pd.read_parquet('train-00000-of-00001.parquet')

# === Preprocessing Function ===
def preprocess(df):
    df.columns = df.columns.astype(str)
    df.fillna('Unknown', inplace=True)
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
    for col in df.columns:
        if 'date' in col:
            df[col] = pd.to_datetime(df[col], errors='coerce')
    return df

# Preprocess datasets
train_csv = preprocess(train_csv)
train_parquet = preprocess(train_parquet)

# Optional: Save cleaned CSVs locally
train_csv.to_csv('cleaned_train.csv', index=False)
train_parquet.to_csv('cleaned_train_parquet.csv', index=False)

print("Preprocessing complete and cleaned CSVs saved.\n")

# === Step 1: Connect to Snowflake ===
conn = connect(
    user='FAHAM2005',
    password='fKrx99Ejj3ZrEAd',
    account='DPNFGOL-FS07172',
    warehouse='BOB',
    database='CULTURAL_ODYSSEY',
    schema='PUBLIC'
)

cursor = conn.cursor()

# === Step 2: Create Tables in Snowflake ===
datasets = {
    'TRAIN_CSV': train_csv,
    'TRAIN_PARQUET': train_parquet
}

for table_name, df in datasets.items():
    cols_with_types = ', '.join([f'"{col}" VARCHAR' for col in df.columns])
    create_table_sql = f"""
    CREATE OR REPLACE TABLE {table_name} (
        {cols_with_types}
    )
    """
    print(f"Creating table {table_name}...")
    cursor.execute(create_table_sql)
    print(f"Table {table_name} created successfully.\n")

print(f"TRAIN_CSV shape: {train_csv.shape}")
print(f"TRAIN_PARQUET shape: {train_parquet.shape}\n")

# === Step 3: Insert Data into Snowflake ===
def insert_data(table_name, df):
    cols = ', '.join([f'"{col}"' for col in df.columns])
    placeholders = ', '.join(['%s'] * len(df.columns))
    insert_sql = f"INSERT INTO {table_name} ({cols}) VALUES ({placeholders})"

    for idx, row in df.iterrows():
        try:
            cursor.execute(insert_sql, tuple(row))
        except Exception as e:
            print(f"Error inserting row {idx} into {table_name}: {e}")
    conn.commit()
    print(f"Inserted {len(df)} rows into {table_name}.\n")

# Insert both datasets
insert_data('TRAIN_CSV', train_csv)
insert_data('TRAIN_PARQUET', train_parquet)

# === Step 4: Verify data insertion ===
for table_name in datasets.keys():
    cursor.execute(f"SELECT COUNT(*) FROM {table_name}")
    count = cursor.fetchone()[0]
    print(f"Total records in {table_name}: {count}")

# === Step 5: Preview some records ===
cursor.execute("SELECT * FROM TRAIN_CSV LIMIT 5")
print("\nSample rows from TRAIN_CSV:")
for row in cursor.fetchall():
    print(row)

cursor.execute("SELECT * FROM TRAIN_PARQUET LIMIT 5")
print("\nSample rows from TRAIN_PARQUET:")
for row in cursor.fetchall():
    print(row)

# === Step 6: Close connection ===
cursor.close()
conn.close()
print("\nSnowflake connection closed.")
# Out:
# Preprocessing complete and cleaned CSVs saved.
#
# Creating table TRAIN_CSV...
# Table TRAIN_CSV created successfully.
#
# Creating table TRAIN_PARQUET...
# Table TRAIN_PARQUET created successfully.
#
# TRAIN_CSV shape: (1000, 4)
# TRAIN_PARQUET shape: (506, 6)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 75
#      72     print(f"Inserted {len(df)} rows into {table_name}.\n")
#      74 # Insert both datasets
# ---> 75 insert_data('TRAIN_CSV', train_csv)
#      76 insert_data('TRAIN_PARQUET', train_parquet)
#      78 # === Step 4: Verify data insertion ===
#
# Cell In[3], line 68, in insert_data(table_name, df)
#      66 for idx, row in df.iterrows():
#      67     try:
# ---> 68         cursor.execute(insert_sql, tuple(row))
#      69     except Exception as e:
#      70         print(f"Error inserting row {idx} into {table_name}: {e}")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\cursor.py:1016, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1009     logger.debug(
#    1010         "query was rewritten: org=%s, new=%s",
#    1011         " ".join(line.strip() for line in query.split("\n")),
#    1012         query1,
#    1013     )
#    1014     query = query1
# -> 1016 ret = self._execute_helper(query, **kwargs)
#    1017 self._sfqid = (
#    1018     ret["data"]["queryId"]
#    1019     if "data" in ret and "queryId" in ret["data"]
#    1020     else None
#    1021 )
#    1022 logger.debug(f"sfqid: {self.sfqid}")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\cursor.py:722, in SnowflakeCursor._execute_helper(self, query, timeout, statement_params, binding_params, binding_stage, is_internal, describe_only, _no_results, _is_put_get, _no_retry, dataframe_ast)
#     720 ret: dict[str, Any] = {"data": {}}
#     721 try:
# --> 722     ret = self._connection.cmd_query(
#     723         query,
#     724         self._sequence_counter,
#     725         self._request_id,
#     726         binding_params=binding_params,
#     727         binding_stage=binding_stage,
#     728         is_file_transfer=bool(self._is_file_transfer),
#     729         statement_params=statement_params,
#     730         is_internal=is_internal,
#     731         describe_only=describe_only,
#     732         _no_results=_no_results,
#     733         _no_retry=_no_retry,
#     734         timeout=real_timeout,
#     735         dataframe_ast=dataframe_ast,
#     736     )
#     737 finally:
#     738     try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\connection.py:1579, in SnowflakeConnection.cmd_query(self, sql, sequence_counter, request_id, binding_params, binding_stage, is_file_transfer, statement_params, is_internal, describe_only, _no_results, _update_current_object, _no_retry, timeout, dataframe_ast)
#    1570     logger.debug(
#    1571         "sql=[%s], sequence_id=[%s], is_file_transfer=[%s]",
#    1572         self._format_query_for_log(data["sqlText"]),
#    1573         data["sequenceId"],
#    1574         is_file_transfer,
#    1575     )
#    1577 url_parameters = {REQUEST_ID: request_id}
# -> 1579 ret = self.rest.request(
#    1580     "/queries/v1/query-request?" + urlencode(url_parameters),
#    1581     data,
#    1582     client=client,
#    1583     _no_results=_no_results,
#    1584     _include_retry_params=True,
#    1585     _no_retry=_no_retry,
#    1586     timeout=timeout,
#    1587 )
#    1589 if ret is None:
#    1590     ret = {"data": {}}
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\network.py:511, in SnowflakeRestful.request(self, url, body, method, client, timeout, _no_results, _include_retry_params, _no_retry)
#     509     headers[HTTP_HEADER_SERVICE_NAME] = self._connection.service_name
#     510 if method == "post":
# --> 511     return self._post_request(
#     512         url,
#     513         headers,
#     514         json.dumps(body, cls=SnowflakeRestfulJsonEncoder),
#     515         token=self.token,
#     516         _no_results=_no_results,
#     517         timeout=timeout,
#     518         _include_retry_params=_include_retry_params,
#     519         no_retry=_no_retry,
#     520     )
#     521 else:
#     522     return self._get_request(
#     523         url,
#     524         headers,
#     525         token=self.token,
#     526         timeout=timeout,
#     527     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\network.py:759, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     756     ret = probe_connection(full_url)
#     757     pprint(ret)
# --> 759 ret = self.fetch(
#     760     "post",
#     761     full_url,
#     762     headers,
#     763     data=body,
#     764     timeout=timeout,
#     765     token=token,
#     766     no_retry=no_retry,
#     767     _include_retry_params=_include_retry_params,
#     768     socket_timeout=socket_timeout,
#     769 )
#     770 logger.debug(
#     771     "ret[code] = {code}, after post request".format(
#     772         code=(ret.get("code", "N/A"))
#     773     )
#     774 )
#     776 if ret.get("code") == MASTER_TOKEN_EXPIRED_GS_CODE:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\network.py:874, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     872 retry_ctx.set_start_time()
#     873 while True:
# --> 874     ret = self._request_exec_wrapper(
#     875         session, method, full_url, headers, data, retry_ctx, **kwargs
#     876     )
#     877     if ret is not None:
#     878         return ret
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\network.py:924, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     922 raise_raw_http_failure = kwargs.pop("raise_raw_http_failure", False)
#     923 try:
# --> 924     return_object = self._request_exec(
#     925         session=session,
#     926         method=method,
#     927         full_url=full_url,
#     928         headers=headers,
#     929         data=data,
#     930         token=token,
#     931         raise_raw_http_failure=raise_raw_http_failure,
#     932         **kwargs,
#     933     )
#     934     if return_object is not None:
#     935         return return_object
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\network.py:1091, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1087 download_start_time = get_time_millis()
#    1088 # socket timeout is constant. You should be able to receive
#    1089 # the response within the time. If not, ConnectReadTimeout or
#    1090 # ReadTimeout is raised.
# -> 1091 raw_ret = session.request(
#    1092     method=method,
#    1093     url=full_url,
#    1094     headers=headers,
#    1095     data=input_data,
#    1096     timeout=socket_timeout,
#    1097     verify=True,
#    1098     stream=is_raw_binary,
#    1099     auth=SnowflakeAuth(token),
#    1100 )
#    1101 download_end_time = get_time_millis()
#    1103 try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\vendored\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\vendored\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\vendored\requests\adapters.py:485, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     482     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     484 try:
# --> 485     resp = conn.urlopen(
#     486         method=request.method,
#     487         url=url,
#     488         body=request.body,
#     489         headers=request.headers,
#     490         redirect=False,
#     491         assert_same_host=False,
#     492         preload_content=False,
#     493         decode_content=False,
#     494         retries=self.max_retries,
#     495         timeout=timeout,
#     496         chunked=chunked,
#     497     )
#     499 except (ProtocolError, OSError) as err:
#     500     raise ConnectionError(err, request=request)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\vendored\urllib3\connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File C:\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File C:\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Python312\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Python312\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\vendored\urllib3\contrib\pyopenssl.py:330, in WrappedSocket.recv_into(self, *args, **kwargs)
#     328         raise
#     329 except OpenSSL.SSL.WantReadError:
# --> 330     if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     331         raise timeout("The read operation timed out")
#     332     else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\vendored\urllib3\util\wait.py:145, in wait_for_read(sock, timeout)
#     141 def wait_for_read(sock, timeout=None):
#     142     """Waits for reading to be available on a given socket.
#     143     Returns True if the socket is readable, or False if the timeout expired.
#     144     """
# --> 145     return wait_for_socket(sock, read=True, timeout=timeout)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\vendored\urllib3\util\wait.py:85, in select_wait_for_socket(sock, read, write, timeout)
#      79 # When doing a non-blocking connect, most systems signal success by
#      80 # marking the socket writable. Windows, though, signals success by marked
#      81 # it as "exceptional". We paper over the difference by checking the write
#      82 # sockets for both conditions. (The stdlib selectors module does the same
#      83 # thing.)
#      84 fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 85 rready, wready, xready = _retry_on_intr(fn, timeout)
#      86 return bool(rready or wready or xready)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\vendored\urllib3\util\wait.py:43, in _retry_on_intr(fn, timeout)
#      42 def _retry_on_intr(fn, timeout):
# ---> 43     return fn(timeout)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\snowflake\connector\cursor.py:711, in SnowflakeCursor._execute_helper.<locals>.interrupt_handler(*_)
#     708         except (ValueError, TypeError):
#     709             # ignore failures
#     710             pass
# --> 711 raise KeyboardInterrupt
#
# KeyboardInterrupt:
